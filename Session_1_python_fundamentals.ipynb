# %% [markdown]
# ###1. Python Output

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello Sumit',1,4.5,True)
# Out:
# Hello Sumit 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='-')
# Out:
# Hello-1-4.5-True

# %%
print('Hello\nsumit\n20')
# Out:
# Hello
# sumit
# 20

# %%
print('Hello',end = '.')
print('sumit')
# Out:
# Hello.sumit

# %%
type('hello')
# Out:
# str

# %% [markdown]
# ##2. Data Types

# %%
#Integer

print(1)

print(1e309)
# Out:
# 1
# inf

# %%
# Float

print(1.45)

print(1.7e309)
# Out:
# 1.45
# inf

# %%
# Boolean

print(True)
# Out:
# True

# %%
# Text/ String

print("Hello world")
# Out:
# Hello world

# %%
# Complex

print(5+6j)
# Out:
# (5+6j)

# %%
# List -> C -> Array

lst = [1,2,3,4,5]

# List is mutable we can change the values

lst[1] = 45

print(lst)
# Out:
# [1, 45, 3, 4, 5]

# %%
# Tuple

tup = (1,2,3,4,5)

# tup[0] = 20
# Tuple is immutable we can't change the values


print(tup[0])
# Out:
# 1

# %%
# Sets

print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary


print({'name' : 'sumit','age' : '22'})
# Out:
# {'name': 'sumit', 'age': '22'}

# %%
# Type

type(3)
# Out:
# int

# %%
type(3.5)
# Out:
# float

# %% [markdown]
# #3. Variables

# %%
# Static vs Dynamic Typing
# Static vs Dynamic Binding
# Stylish declaration techniques

# %%
name = 'sumit'

a = 5
b = 6

print(name)
print(5+6)
# Out:
# sumit
# 11

# %%
# Dynamic Typing

# Python interpreter automatically understands the type of varibale

a = 5

# Static Typing

# int a = 5

# %%
# Dynamic Binding

# You can change the datatype anytime

a = 5
print(a)

a = 'sumit'
print(a)

# Static Binding

# int a = 5;
# Out:
# 5
# sumit

# %%
a,b,c = 1,2,3

print(a,b,c)
# Out:
# 1 2 3

# %%
a = b = c = 5

print(a,b,c, sep='\n')
# Out:
# 5
# 5
# 5

# %% [markdown]
# #4. Keywords and Identifiers

# %%
# Reserved words which compiler uses to cover High lvl lang to Low lvl lang


# Identifiers are the names of the variable which we use in our program

# 1. Can't start with a digit
# 2. use of only _ special char

# %% [markdown]
# #5. User Input

# %%
input("enter email")
# Out:
# enter emailrawatsumit1290@gmail.com
# 'rawatsumit1290@gmail.com'

# %% [markdown]
# #6. Type Conversion

# %%
# write a program to add two numbers

fnum = int(input("enter your fnum"))

snum = int(input("enter your snum"))

result = fnum + snum

print(result)
# Out:
# enter your fnum5
# enter your snum6
# 11

# %% [markdown]
# #7. Literals

# %%
a = 0b1010 #Binary Literal

b = 100 # decial literal

c = 0o310 # Octal literal

d = 0x12c # Hexadecimal literal


# Float Literal

float_1 = 10.5
float_2 = 1.5e2
float_3 = 1.5e-3

print(float_3)
# Out:
# 0.0015

# %%
string = 'This is python'

string = "this is python"

char = "C"

multiline = """Hello Sumit"""

raw_str = r"raw \n string"

print(raw_str)
# Out:
# raw \n string

# %% [markdown]
# #8. Operators
