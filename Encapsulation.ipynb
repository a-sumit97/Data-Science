# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

  def __str__(self):
    return '{},{}'.format(self.name,self.gender)

def greet(person):
    person.name = 'sumit'
    return person

p = Person('madri','male')
print(p)
print(id(p))
p1 = greet(p)
print(p)
print(id(p1))
# Out:
# madri,male
# 136831876636528
# sumit,male
# 136831876636528

# %% [markdown]
# #Encapsulation

# %%
#instance variable (special type of variable jiski value object ke upar depend krta h )

class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('sumit','male')
p2 = Person('madri','male')

# %%
p1.name
# Out:
# 'sumit'

# %%
p2.name
# Out:
# 'madri'

# %%
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0  # __ to create private
    self.__menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 136831868947824
#
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     2
# enter old pin123
# nai karne de sakta re baba

# %%
obj.pin = 'hello'

# %%
obj.create_pin()
# Out:
# enter your pin1234
# enter balance100000
# pin created successfully

# %%
obj._Atm__balance = 'hehe' # can be changed from outsie the class

# any junior programmer can change the variable outside the class

# %%
obj.withdraw()
# Out:
# enter the pin1234
# enter the amount10000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3797629794.py in <cell line: 0>()
# ----> 1 obj.withdraw()
#
# /tmp/ipython-input-2836259181.py in withdraw(self)
#      70       # allow to withdraw
#      71       amount = int(input('enter the amount'))
# ---> 72       if amount <= self.__balance:
#      73         self.__balance = self.__balance - amount
#      74         print('withdrawl successful.balance is',self.__balance)
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
obj.__balance = 1000 #it will not affect the code

# %% [markdown]
# #What really happen inside class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class person:

    def __init__(self):
        self.__name= 'sumit'

p1 = person()
p1.__name = 'ashu'

p1._person__name = 'ashu'
print(p1._person__name)

# visualize it in python tutor you will get to know that if we change the variable to private variable it's
# name will not be __name it will change to _classname__variablename
# Out:
# ashu

# %%
# PYTHON IS A LANGUAGE USED BY SMART PEOPLE AND IT'S A GENTLEMEN AGGREMENT TO NOT USED SOMEONE'S PRIVATE VARIABLES

# %%
# Suppose someone your new junior wants to access the private members how can he use them

# getter and setter

# private members means that outside the class people can't access it but inside class methods can access it

class person:

  def __init__(self):
    self.__name = 'sumit'
    self.__age = 21

  def getter(self):
    return self.__name,self.__age

  def setter(self,name,age):
    self.__name = name
    if type(age) != int:
      print('int daal de ')
    else:
      self.__age = age

p1 = person()

# %%
p1.getter()
# Out:
# ('sumit', 21)

# %%
p1.setter('ashu','female')
# Out:
# int daal de

# %%
p1.setter('ashu',22) # you can add a check to your setter

# %%
p1.getter()
# Out:
# ('ashu', 22)

# %%
class person:

  def __init__(self):

# %%
#list of objects

class person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = person('sumit','male')
p2 = person('ashu','female')
p3 = person('sumit','male')

L = [p1,p2,p3]

# %%
L

# %%
for i in L:
  print(i.name,i.gender)
# Out:
# sumit male
# ashu female
# sumit male

# %%
S = {p1,p2,p3}

for i in S:
  print(i.name,i.gender)
# Out:
# sumit male
# ashu female
# sumit male

# %%
d= {'p1':p1,'p2':p2,'p3':p3}

for i in d:
  print(d[i].name,d[i].gender)
# Out:
# sumit male
# ashu female
# sumit male

# %% [markdown]
# #Static Variable(vs Instance Variable)

# %%
class Atm:


  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0  # __ to create private
    # self.__menu()
    self.cust_Id = 0
    self.cust_Id += 1

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
cus1 = Atm()
# Out:
# 135298915241568

# %%
cus2 = Atm()
# Out:
# 135298913419392

# %%
cus3 = Atm()
# Out:
# 135298913421360

# %%
cus1.cust_Id
# Out:
# 1

# %%
cus2.cust_Id
# Out:
# 1

# %%
cus3.cust_Id
# Out:
# 1

# %% [markdown]
# #Static Variable vs Instance Variable
#
# ###instance varibale changes for every object
# ###static variabe is same for every object
#
# ##instance variable ek object ka hota h and usko access krne ka method
#
# objectname.variablename
#
# constructor ke andr declare hota h
#
# ##static variable ek class ka hota h and usko access krne ka method
#
# classname.variablename
#
# class ke andr declare hota h

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Atm:

  __cust_id = 1 # private
  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0  # __ to create private
    # self.__menu()
    self.cust_id = Atm.__cust_id
    Atm.__cust_id = Atm.__cust_id + 1

  #utility functions : chote mote func ke liye jinke liye obj ki need ni h
  @staticmethod
  def get_counter(): # can create method without self and we can access it with class name Atm.get_counter()
    return Atm.__cust_id



  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
c2 = Atm()
c3 = Atm()
# Out:
# 135298911894224
# 135298911886928
# 135298911889184

# %%
c1.cust_id
# Out:
# 1

# %%
c2.cust_id
# Out:
# 2

# %%
c3.cust_id
# Out:
# 3

# %%
Atm.cust_id = 'hehe' # make it private

# %%
c1 = Atm()
# c1.get_counter()
# Out:
# 135298913428176

# %%
Atm.get_counter()
# Out:
# 5
