# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# #Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series from lists

# %%
#strings

a = ['india','pakistan','russia','china','japan','switzerland']

pd.Series(a)
# Out:
# 0          india
# 1       pakistan
# 2         russia
# 3          china
# 4          japan
# 5    switzerland
# dtype: object

# %%
b = [15,67,89,45,81]

pd.Series(b)
# Out:
# 0    15
# 1    67
# 2    89
# 3    45
# 4    81
# dtype: int64

# %%
#custom index

marks = [99,91,93,81]
subjects = ['maths','science','english','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths      99
# science    91
# english    93
# hindi      81
# dtype: int64

# %%
# setting a name

marks = pd.Series(marks,index=subjects, name = 'sumit')
marks
# Out:
# maths      99
# science    91
# english    93
# hindi      81
# Name: sumit, dtype: int64

# %% [markdown]
# #Series from dict

# %%
marks = {
    'maths' : 99,
    'hindi' : 91,
    'science' : 93,
    'english' : 81
}

marks_series = pd.Series(marks,name = 'sumit')
marks_series
# Out:
# maths      99
# hindi      91
# science    93
# english    81
# Name: sumit, dtype: int64

# %% [markdown]
# #Series Attributes

# %%
#size

marks_series.size
# Out:
# 4

# %%
#dtype

marks_series.dtype
# Out:
# dtype('int64')

# %%
#name

marks_series.name
# Out:
# 'sumit'

# %%
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,2,1,4]).is_unique
# Out:
# False

# %%
#index

marks_series.index
# Out:
# Index(['maths', 'hindi', 'science', 'english'], dtype='object')

# %%
#values

marks_series.values
# Out:
# array([99, 91, 93, 81])

# %% [markdown]
# #Read from csv

# %%
pd.read_csv('/content/subs.csv')
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs = pd.read_csv('/content/subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('/content/kohli_ipl.csv', index_col = 'match_no').squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
#head and tail

movies.head()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
movies.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movies.head(3)
# Out:
# movie
# Uri: The Surgical Strike                Vicky Kaushal
# Battalion 609                             Vicky Ahuja
# The Accidental Prime Minister (film)      Anupam Kher
# Name: lead, dtype: object

# %%
#sample

movies.sample()
# Out:
# movie
# Mercury (film)    Prabhu Deva
# Name: lead, dtype: object

# %%
movies.sample(5)
# Out:
# movie
# Guzaarish (film)       Hrithik Roshan
# Bhaag Johnny              Kunal Khemu
# 1920 (film)          Rajniesh Duggall
# Gold (2018 film)         Akshay Kumar
# Daas Dev            Yogesh Raj Mishra
# Name: lead, dtype: object

# %%
#value_counts - > movie

movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
#sort_values - > inplace

movies.sort_values()
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_values(ascending=False).head(3)
# Out:
# movie
# Taj Mahal: An Eternal Love Story    Zulfi Sayed
# Dil Toh Deewana Hai                 Zeenat Aman
# Strings of Passion                  Zeenat Aman
# Name: lead, dtype: object

# %%
#sort_index - > inplace

movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index(inplace = True) # permanent changes

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# #Series Maths Methods

# %%
#count

vk.count()
# Out:
# np.int64(215)

# %%
#sum - > Product

vk.sum()
# Out:
# np.int64(6634)

# %%
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var

vk.mean()
# Out:
# np.float64(30.855813953488372)

# %%
print(vk.median())
print(movies.mode())
print(vk.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 26.22980132830278
# 688.0024777222344

# %%
#mix/max

subs.min()
# Out:
# 33

# %%
subs.max()
# Out:
# 396

# %%
# describe

subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# #Series Indexingg

# %%
# integer indexing

x = pd.Series(np.random.randint(1,10,10))
x[0]
# Out:
# np.int64(3)

# %%
# negative indexing

x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3393693259.py in <cell line: 0>()
#       1 # negative indexing
#       2
# ----> 3 x[-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
movies[0]
# Out:
# /tmp/ipython-input-3901301928.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[0]
# 'Vicky Kaushal'

# %%
movies[-1]
# Out:
# /tmp/ipython-input-2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Akshay Kumar'

# %%
#positive indexing

movies[0:5]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
# negative indexing

movies[-5:-1]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Name: lead, dtype: object

# %%
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing

vk[[1,3,5]]
# Out:
# match_no
# 1     1
# 3    13
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing

movies['Awara Paagal Deewana']
# Out:
# 'Akshay Kumar'

# %% [markdown]
# # Editing Series

# %%
#using indexing

marks_series[0] = 100
marks_series
# Out:
# /tmp/ipython-input-3684879737.py:3: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[0] = 100
# maths      100
# hindi       91
# science     93
# english     81
# Name: sumit, dtype: int64

# %%
marks_series
# Out:
# [100, 91, 93, 81, 80]

# %%
# what if an index doesn't exist

marks_series['sst']  = 80
marks_series
# Out:
# maths      100
# hindi       91
# science     93
# english     81
# sst         80
# Name: sumit, dtype: int64

# %%
  # slicing

  runs_ser = pd.Series(np.random.randint(10,100,10))
  runs_ser
# Out:
# 0    64
# 1    39
# 2    28
# 3    23
# 4    42
# 5    75
# 6    49
# 7    27
# 8    31
# 9    14
# dtype: int64

# %%
runs_ser[3:5] = [100,100]
runs_ser
# Out:
# 0     64
# 1     39
# 2     28
# 3    100
# 4    100
# 5     75
# 6     49
# 7     27
# 8     31
# 9     14
# dtype: int64

# %%
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0     0
# 1    39
# 2    28
# 3     0
# 4     0
# 5    75
# 6    49
# 7    27
# 8    31
# 9    14
# dtype: int64

# %%
# using index labels

movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies['Awara Paagal Deewana'] = 'Sumit Rawat'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                         Sumit Rawat
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Series with Python Functionalities

# %%
#len/type/dir/sorted/min/max

print(len(marks_series))
print(type(marks_series))
print(dir(marks_series))
print(sorted(marks_series)) # stores in list
print(min(marks_series))
print(max(marks_series))
# Out:
# 5
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion

list(marks_series)
# Out:
# [99, 91, 93, 81]

# %%
dict(marks_series)
# Out:
# {'maths': np.int64(99),
#  'hindi': np.int64(91),
#  'science': np.int64(93),
#  'english': np.int64(81)}

# %%
# membership operator

'Aankhen (2002 film)'  in movies # works only in index not in values
# Out:
# True

# %%
'Sumit Rawat' in movies.values
# Out:
# True

# %%
# looping

for i in movies:
  print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in movies.index:
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# arithmetic operators

runs_ser
# Out:
# 0     0
# 1    39
# 2    28
# 3     0
# 4     0
# 5    75
# 6    49
# 7    27
# 8    31
# 9    14
# dtype: int64

# %%
runs_ser + 2
# Out:
# 0     2
# 1    41
# 2    30
# 3     2
# 4     2
# 5    77
# 6    51
# 7    29
# 8    33
# 9    16
# dtype: int64

# %%
marks_series
# Out:
# maths      99
# hindi      91
# science    93
# english    81
# Name: sumit, dtype: int64

# %%
100 - marks_series #( Broadcasting )
# Out:
# maths       1
# hindi       9
# science     7
# english    19
# Name: sumit, dtype: int64

# %%
# relational operators

vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[vk > 50]
# Out:
# match_no
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %% [markdown]
# #Boolean Indexing on Series

# %%
# find no's of 50s and 100s scored by vk

vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks

vk[vk == 0].size
# Out:
# 9

# %%
# count no of days when I had more than 200 subs in one day

subs[subs > 200].size
# Out:
# 59

# %%
#find actors who have done more than 20 movies

num_movies = movies.value_counts()

# %%
num_movies
# Out:
# lead
# Akshay Kumar        47
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Nandita Das          1
# Kapil Jhaveri        1
# Amar Upadhyaya       1
# Sameera Reddy        1
# Prit Kamani          1
# Name: count, Length: 567, dtype: int64

# %%
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        47
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# # Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(5).plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
movies.value_counts().head(5).plot(kind = 'bar')
# Out:
# <Axes: xlabel='lead'>
