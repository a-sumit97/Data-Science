# %% [markdown]
# #Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# #Aggregation (Has a Relationship)

# %%
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.city,self.address.pin,self.address.state)

class Address:

  def __init__(self,city,pin,state):
    self.city = city
    self.pin = pin
    self.state = state

add1 = Address('new delhi','110001','delhi')
cust = Customer('john','male',add1)

# %%
cust.print_address()
# Out:
# new delhi 110001 delhi

# %%
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(),self.address.pin,self.address.state)

  def edit_profile(self,new_name,new_city,new_pin,new_state):
    self.name = new_name
    self.address.edit_address(new_city,new_pin,new_state)

class Address:

  def __init__(self,city,pin,state):
    self.__city = city
    self.pin = pin
    self.state = state

  def get_city(self):
    return self.__city

  def edit_address(self,new_city,new_pin,new_state):
    self.__city = new_city
    self.pin = new_pin
    self.state = new_state

add1 = Address('new delhi','110001','delhi')
cust = Customer('john','male',add1)

# %%
cust.print_address() #You can't access private member when you are using aggregation
# Out:
# new delhi 110001 delhi

# %%
cust.name
# Out:
# 'john'

# %%
cust.gender
# Out:
# 'male'

# %%
cust.edit_profile('sumit','mumbai',202021,'maharastra')

# %%
cust.print_address()
# Out:
# mumbai 202021 maharastra

# %% [markdown]
# #Class Diagram of Aggregation
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Inheritance
#
# - what is inheritance?
# - example
# - what gets inherited?

# %% [markdown]
# #Code reuseability
#
# ![image.png](data:image/png;base64,...)

# %%
#Example


# Parent Class
class User():

  def __init__(self):
    self.name = 'sumit'

  def login(self):
    print('hello')


# Child Class
class Student(User):

  def enroll(self):
    print('enroll')

# %%
stu = Student()

# %%
stu.enroll()
stu.login()  # you can access parent class methods and variables
print(stu.name)
# print(stu.rollno)
# Out:
# enroll
# hello
# sumit

# %%
u = User()

# %% [markdown]
# #What gets Inherited?
#
# - Constructor
# - Non private attribute/ variable
# - Non private methods

# %% [markdown]
# #Class Diagram
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #DRY ( Don't Repeat Yourself )
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Constructor Example

class Phone():

  def __init__(self,price,brand,camera):
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("buying a phone")

class SmartPhone(Phone):
  pass

# agar child ke pass khudka constructor nhi hota to parent ka constructor call hota h

# %%
s = SmartPhone(1500000,'iphone',30)
s.buy()
# Out:
# buying a phone

# %%
s.price
# Out:
# 1500000

# %%
s.brand
# Out:
# 'iphone'

# %%
# constructor example 2

class Phone():

  def __init__(self,price,brand,camera):
    print("inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("buying a phone")

class SmartPhone(Phone):

  def __init__(self,os,ram):
    self.os = os
    self.ram = ram
    print("inside SmartPhone constructor")

  def buy(self):
    print('buying a smartphone')

s = SmartPhone('android',2)
s.buy()

# Agar child ke pass khudka constructor h to parent ka constructor call ni hoga
# Out:
# inside SmartPhone constructor
# buying a smartphone

# %%
s.brand

# ye error throw krega kyuki kbhi wo variables initialize hi nhi hue
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4068866006.py in <cell line: 0>()
# ----> 1 s.brand
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %%
# child can't access private members of the class

class Phone:

  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  #getter ( we can see the private member using getter )
  def show(self):
    print(self.__price)

  def setter(self,price):
    self.__price = price

class SmartPhone(Phone):

  def check(self):
    print(self.__price)

s = SmartPhone(20000,"Iphone",13)
# s.check() this will throw an error

s.brand
s.camera
s.show()

s.setter(250000)
s.show()
# Out:
# Inside Phone Constructor
# 20000
# 250000

# %%
class Phone:

  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def __show(self):
    print(self.__price)

class SmartPhone(Phone):

  def check(self):
    print(self.__price)

s = SmartPhone(20000,"Iphone",13)
# s.check() this will throw  an error

s.brand
s.camera
s.show() # we can't access private members as well as methods
# Out:
# Inside Phone Constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1392103027.py in <cell line: 0>()
#      20 s.brand
#      21 s.camera
# ---> 22 s.show()
#
# AttributeError: 'SmartPhone' object has no attribute 'show'

# %%
class Parent:

  def __init__(self,num):
    self.__num = num

  def get_num(self):
    return self.__num

class Child(Parent):

  def show(self):
    print("Inside child class")

son = Child(100)
print("Parent Number : ",son.get_num())
son.show()
# Out:
# Parent Number :  100
# Inside child class

# %%
class Parent:

  def __init__(self,num):
    self.__num = num

  def get_num(self):
    return self.__num

class Child(Parent):

  def __init__(self,val,num):
    self.__val = val

  def get_val(self):
    return self.__val

son = Child(100,10)
print("Parent Number : ",son.get_num())  # Parent func was never called
print("Child Number : ",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-241372833.py in <cell line: 0>()
#      16
#      17 son = Child(100,10)
# ---> 18 print("Parent Number : ",son.get_num())
#      19 print("Child Number : ",son.get_val())
#
# /tmp/ipython-input-241372833.py in get_num(self)
#       5
#       6   def get_num(self):
# ----> 7     return self.__num
#       8
#       9 class Child(Parent):
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:

  def __init__(self):
    self.var1 = 100

  def display1(self,var1):
    print("class A : ",self.var1)

class B(A):

  def display2(self,var1):
    print("clas B : ",self.var1)

obj = B()
obj.display1(200)
# Out:
# class A :  100

# %%
#Method overriding

class Phone:

  def __init__(self,price,camera,brand):
    print("Inside parent Constructor")
    self.__price = price
    self.camera = camera
    self.brand = brand

  def buy(self):
    print("Buying a Phone")

class SmartPhone(Phone):

  def buy(self):
    print("Buying a Child")

obj = SmartPhone(1200000,20,'iphone')
obj.buy()
# Out:
# Inside parent Constructor
# Buying a Child

# %% [markdown]
# #Super Keyword
#
# - Super is used inside the child class
# - Super can't be used outside the child class
# - Super can't access attributes/variables
# - Super can access methods

# %%
class Phone():

  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")

class SmartPhone(Phone):

  def buy(self):
    print("Buying a SmartPhone")
    # syntax to call parent ka buy method
    super().buy()

s = SmartPhone(20000,"Iphone",13)
s.buy()
# Out:
# Inside Phone Constructor
# Buying a SmartPhone
# Buying a Phone

# %%
#Super -> Constructor

# %%
class Phone():

  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.price = price
    self.brand = brand
    self.camera = camera

class SmartPhone(Phone):

  def __init__(self,price,brand,camera,os,ram):
    print("Inside SmartPhone Constructor")
    super().__init__(price,brand,camera)
    self.os = os
    self.ram = ram


s = SmartPhone(20000,"Iphone",12,'android',2)

print(s.os)
print(s.brand)
# Out:
# Inside SmartPhone Constructor
# Inside Phone Constructor
# android
# Iphone

# %%
class Phone():

  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")

class SmartPhone(Phone):

  def buy(self):
    print("Buying a SmartPhone")

s = SmartPhone(20000,"Iphone",13)
super().buy() # you can't call super outside the class
# it's always used inside the child class
# Out:
# Inside Phone Constructor
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2685374375.py in <cell line: 0>()
#      16
#      17 s = SmartPhone(20000,"Iphone",13)
# ---> 18 super().buy()
#
# RuntimeError: super(): no arguments

# %%
# You can't access attribute of parent class using super, you can only access methods of parent class

class Phone():

  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")

class SmartPhone(Phone):

  def buy(self):
    print("Buying a SmartPhone")
    print(super().brand)


s = SmartPhone(20000,"Iphone",13)
s.buy()
# Out:
# Inside Phone Constructor
# Buying a SmartPhone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1650321415.py in <cell line: 0>()
#      20
#      21 s = SmartPhone(20000,"Iphone",13)
# ---> 22 s.buy()
#
# /tmp/ipython-input-1650321415.py in buy(self)
#      16   def buy(self):
#      17     print("Buying a SmartPhone")
# ---> 18     print(super().brand)
#      19
#      20
#
# AttributeError: 'super' object has no attribute 'brand'

# %% [markdown]
# # Inheritance in Summary
#
# - A class can inherit from another class
# - Inheritance improves code reusability
# - Constructor, attributes, methods get inherited to child class
# - The parent has no access to child class
# - Private properties of parent aren't directly accessible in child class
# - Child class can override the attributes or methods. This is called method overriding
# - super() is an inbuilt function which is used to invoke the parent class method and constructor

# %%
class Parent:

  def __init__(self,num):
    self.__num = num

  def get_num(self):
    return self.__num

class Child(Parent):

  def __init__(self,num,val):
    super().__init__(num)
    self.__val = val

  def get_val(self):
    return self.__val

son = Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:

  def __init__(self):
    self.num = 100

class Child(Parent):

  def __init__(self):
    super().__init__()
    self.var = 200

  def show(self):
    print(self.num)
    print(self.var)

obj = Child()
obj.show()
# Out:
# 100
# 200

# %%
class Parent:

  def __init__(self):
    self.__num = 100

  def display(self):
    print("inside parent class : ",self.__num)

class Child(Parent):

  def __init__(self):
    super().__init__()
    self.__var = 200

  def display(self):
    print("inside child class : ",self.__var)

obj = Child()
obj.display()
# Out:
# inside child class :  200

# %% [markdown]
# #Types of Inheritance
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Single Level Inheritance
# - Multi Level
# -  Hierarchial
# - Multiple
# - Hybrid

# %%
#single inheritance

class Phone:

  def __init__(self,price,brand,camera):
    print("inside Phone class")
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a phone")

class SmartPhone(Phone):

  pass

s = SmartPhone(20000,"Apple","13px")
s.buy()
# Out:
# inside Phone class
# Buying a phone

# %%
# multilevel Inheritance

class Product:

  def review(self):
    print("Product customer review")

class Phone(Product):

  def __init__(self,price,brand,camera):
    print("inside Phone class")
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a phone")

class SmartPhone(Phone):

  pass

s = SmartPhone(20000,"Apple","13px")
s.buy()
s.review()
# Out:
# inside Phone class
# Buying a phone
# Product customer review

# %%
# Hierarchial

class Phone:

  def __init__(self,price,brand,camera):
    print("inside Phone class")
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")

class SmartPhone(Phone):

  pass

class FeaturePhone(Phone):

  pass

s = SmartPhone(20000,"Apple","13px")
s.buy()

FeaturePhone(20000,"Apple","13px").buy()
# Out:
# inside Phone class
# Buying a Phone
# inside Phone class
# Buying a Phone

# %%
# Multiple Class

class Phone:

  def __init__(self,price,brand,camera):
    print("Inside phone class")
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("buying a phone")

class Product:

  def review(self):
    print("Customer review")

class SmartPhone(Phone,Product):

  pass

SmartPhone(15000,'Iphone',13).review()
# Out:
# Inside phone class
# Customer review

# %%
# The diamond problem

class Phone:

  def __init__(self,price,brand,camera):
    print("Inside phone class")
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("buying a phone")

class Product:

  def buy(self):
    print("Customer review")

# Method Resolution Order
class SmartPhone(Phone,Product): # Priority is give to Phone

  pass

SmartPhone(15000,'Iphone',13).buy()
# Out:
# Inside phone class
# buying a phone

# %%
class A:

  def m1(self):
    return 20

class B(A):

  def m1(self):
    return 30

  def m2(self):
    return 40

class C(B):

  def m2(self):
    return 20

obj1 = A()
obj2 = B()
obj3 = C()

print(obj1.m1()+obj3.m1()+obj3.m2())
# Out:
# 70

# %%
class A():

  def m1(self):
    return 20

class B(A):

  def m1(self):
    val = super().m1() + 30
    return val

class C(B):

  def m1(self):
    val = self.m1() + 20


obj = C()
print(obj.m1())
   # method overriding infinite loop
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %% [markdown]
# #Polymorphism
#
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %%
# Method Overloading is not allowed in python

class Shape:

  def area(self,radius):
    return 3.14*radius*radius

  def area(self,l,b):
    return l*b

s = Shape()

s.area(4)
s.area(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1484817589.py in <cell line: 0>()
#       9 s = Shape()
#      10
# ---> 11 s.area(4)
#      12 s.area(3,4)
#
# TypeError: Shape.area() missing 1 required positional argument: 'b'

# %%
class Shape:

  def area(self,a,b=0):
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

s.area(4)
# s.area(3,4)
# Out:
# 50.24

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
5 + 4
# Out:
# 9

# %%
[1,2,3] + [4,5]
# Out:
# [1, 2, 3, 4, 5]
